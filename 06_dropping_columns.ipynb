# %% [markdown]
# # Dropping Columns
# Abid Ali
# https://github.com/abid-2362
#
#
# #### Pandas drop()

# %%
import pandas as pd

data = pd.read_csv('./data/artwork_sample.csv')

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
# dropping rows - inplace is False by default
data.drop(0, inplace=False)
# Out:
#      id accession_number          artist artistRole  artistId  \
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# ...

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
# KeyError: "['id'] not found in axis"
data.drop('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 data.drop('id')
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
# ...

# %%
data.drop('id', axis=1)
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
# columns can be dropped with columns param instead of axis as well
data.drop(columns=['id'])
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
data.drop(columns=['id', 'height', 'width', 'depth'])
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
# removing rows with labels parameter
data.drop(labels=[0, 1, 2])
# Out:
#      id accession_number          artist artistRole  artistId  \
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# ...

# %%
help(data.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis: 'Axis' = 0, index=None, columns=None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'str' = 'raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the `user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
# ...

# %%
import numpy as np
data.drop(labels=np.arange(2,6))
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# 8                 The Serpent Attacking Buoso Donati  1826–7, reprinted 1892
# ...

# %%
data = pd.read_csv('./data/artwork_sample.csv')

# %%
# data.drop(labels=[x>5 for x in data.index])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 data.drop(labels=[x>5 for x in data.index])
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
# ...

# %%
data.drop(columns=['id'], inplace=True)

# %%
data
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
# since data does not have id column now, if we try to drop it again, it will raise error
data.drop(columns=['id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # since data does not have id column now, if we try to drop it again, it will raise error
# ----> 2 data.drop(columns=['id'])
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
# ...

# %%
# read only required columns of data from csv file
data = pd.read_csv('./data/artwork_sample.csv', usecols=['artist', 'title'])
data
# Out:
#            artist                                              title
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6  Blake, William                        The Baffled Devils Fighting
# 7  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8  Blake, William                 The Serpent Attacking Buoso Donati
# 9  Blake, William                 The Pit of Disease: The Falsifiers
